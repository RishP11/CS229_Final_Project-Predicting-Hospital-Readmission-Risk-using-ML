# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, classification_report, roc_curve, auc
from catboost import CatBoostClassifier
import catboost
import optuna

# %% [markdown]
# Bootstrapping method to find the confidence interval of the AUROC score

# %%
def bootstrap_auc_ci(y_true, y_scores, n_bootstraps=2000, ci=0.95):
    rng = np.random.default_rng(42)
    aucs = []

    y_true = np.array(y_true)
    y_scores = np.array(y_scores)

    for _ in range(n_bootstraps):
        idx = rng.integers(0, len(y_true), len(y_true))
        if len(np.unique(y_true[idx])) < 2:
            continue
        aucs.append(roc_auc_score(y_true[idx], y_scores[idx]))

    lower = np.percentile(aucs, (1 - ci) / 2 * 100)
    upper = np.percentile(aucs, (1 + ci) / 2 * 100)
    return np.mean(aucs), lower, upper

# %% [markdown]
# Loading the dataset, pre-processing, and analysing the data

# %%
cohort_data = pd.read_csv('../cohort_data_new.csv')
cohort_data
# Out:
#        icustay_id  anion_gap_mean  anion_gap_sd  anion_gap_min  anion_gap_max  \
# 0          200003       13.375000      3.583195            9.0           21.0
# 1          200007       15.500000      2.121320           14.0           17.0
# 2          200009        9.500000      2.121320            8.0           11.0
# 3          200012             NaN           NaN            NaN            NaN
# 4          200014       10.000000      1.732051            9.0           12.0
# ...           ...             ...           ...            ...            ...
# 30484      299992       15.375000      2.856153           11.0           25.0
# 30485      299993        9.400000      1.341641            8.0           11.0
# 30486      299994       16.157895      2.477973           13.0           24.0
# 30487      299998       11.500000      1.732051           10.0           14.0
# 30488      299999             NaN           NaN            NaN            NaN
#
#        bicarbonate_mean  bicarbonate_sd  bicarbonate_min  bicarbonate_max  \
# 0             25.250000        3.105295             18.0             28.0
# 1             23.000000        1.414214             22.0             24.0
# 2             23.333333        2.081666             21.0             25.0
# 3                   NaN             NaN              NaN              NaN
# 4             24.000000        1.000000             23.0             25.0
# ...                 ...             ...              ...              ...
# 30484         23.125000        2.609556             15.0             26.0
# 30485         29.600000        2.073644             26.0             31.0
# 30486         21.631579        3.451417             17.0             31.0
# 30487         23.500000        1.290994             22.0             25.0
# 30488         24.000000             NaN             24.0             24.0
#
#        calcium_total_mean  ...  urea_nitrogen_min  urea_nitrogen_max  \
# 0                7.771429  ...               10.0               21.0
# 1                8.900000  ...                8.0               10.0
# 2                8.000000  ...               15.0               21.0
# 3                     NaN  ...                NaN                NaN
# 4                7.733333  ...               21.0               24.0
# ...                   ...  ...                ...                ...
# 30484            8.307143  ...                8.0               23.0
# 30485            8.000000  ...               12.0               15.0
# 30486            8.100000  ...               28.0               63.0
# 30487            8.800000  ...               20.0               22.0
# 30488                 NaN  ...               11.0               13.0
#
#        white_blood_cells_mean  white_blood_cells_sd  white_blood_cells_min  \
# 0                   26.471429             13.176711                   13.2
# 1                   10.300000              1.272792                    9.4
# 2                   12.471429              1.471637                   10.5
# 3                    4.900000                   NaN                    4.9
# 4                   13.233333              2.203028                   10.7
# ...                       ...                   ...                    ...
# 30484               14.134783              3.781727                    8.1
# 30485               12.600000              0.605530                   12.0
# 30486               10.076190              2.642329                    5.3
# 30487                9.900000              1.210372                    7.9
# 30488               18.300000              3.394113                   15.9
#
#        white_blood_cells_max  age  gender  icu_los_hours  target
# 0                       43.9   48       M            141       0
# 1                       11.2   44       M             30       0
# 2                       14.3   47       F             51       0
# 3                        4.9   33       F             10       0
# 4                       14.7   85       M             41       0
# ...                      ...  ...     ...            ...     ...
# 30484                   22.1   41       M            499       0
# 30485                   13.3   26       M             67       0
# 30486                   14.5   74       F            152       1
# 30487                   11.0   87       M             46       1
# 30488                   20.7   49       M             31       0
#
# [30489 rows x 93 columns]

# %%
print(f"Dataset shape: {cohort_data.shape}")
print(f"Readmission rate: {cohort_data['target'].mean() * 100:.2f}%")
# Out:
# Dataset shape: (30489, 93)
# Readmission rate: 10.74%

# %%
lab_cols = [
    'anion_gap_mean', 'anion_gap_min', 'anion_gap_max', 'anion_gap_sd',
    'bicarbonate_mean', 'bicarbonate_min', 'bicarbonate_max', 'bicarbonate_sd',
    'calcium_total_mean', 'calcium_total_min', 'calcium_total_max', 'calcium_total_sd',
    'chloride_mean', 'chloride_min', 'chloride_max', 'chloride_sd',
    'creatinine_mean', 'creatinine_min', 'creatinine_max', 'creatinine_sd',
    'glucose_mean', 'glucose_min', 'glucose_max', 'glucose_sd',
    'hematocrit_mean', 'hematocrit_min', 'hematocrit_max', 'hematocrit_sd',
    'hemoglobin_mean', 'hemoglobin_min', 'hemoglobin_max', 'hemoglobin_sd',
    'mchc_mean', 'mchc_min', 'mchc_max', 'mchc_sd',
    'mcv_mean', 'mcv_min', 'mcv_max', 'mcv_sd',
    'magnesium_mean', 'magnesium_min', 'magnesium_max', 'magnesium_sd',
    'pt_mean', 'pt_min', 'pt_max', 'pt_sd',
    'phosphate_mean', 'phosphate_min', 'phosphate_max', 'phosphate_sd',
    'platelet_count_mean', 'platelet_count_min', 'platelet_count_max', 'platelet_count_sd',
    'potassium_mean', 'potassium_min', 'potassium_max', 'potassium_sd',
    'rdw_mean', 'rdw_min', 'rdw_max', 'rdw_sd',
    'red_blood_cells_mean', 'red_blood_cells_min', 'red_blood_cells_max', 'red_blood_cells_sd',
    'sodium_mean', 'sodium_min', 'sodium_max', 'sodium_sd',
    'urea_nitrogen_mean', 'urea_nitrogen_min', 'urea_nitrogen_max', 'urea_nitrogen_sd',
    'white_blood_cells_mean', 'white_blood_cells_min', 'white_blood_cells_max', 'white_blood_cells_sd',
    'age', 'icu_los_hours'
]

# %% [markdown]
# REmove the ICUstay_id and the gender

# %%
drop_cols = [c for c in cohort_data.columns if 'icustay_id' in c.lower() or 'gender' in c.lower()]
df = cohort_data.drop(columns=['icustay_id', 'gender'], errors='ignore')

X = df.drop(columns=['target'])
y = df['target']
X
# Out:
#        anion_gap_mean  anion_gap_sd  anion_gap_min  anion_gap_max  \
# 0           13.375000      3.583195            9.0           21.0
# 1           15.500000      2.121320           14.0           17.0
# 2            9.500000      2.121320            8.0           11.0
# 3                 NaN           NaN            NaN            NaN
# 4           10.000000      1.732051            9.0           12.0
# ...               ...           ...            ...            ...
# 30484       15.375000      2.856153           11.0           25.0
# 30485        9.400000      1.341641            8.0           11.0
# 30486       16.157895      2.477973           13.0           24.0
# 30487       11.500000      1.732051           10.0           14.0
# 30488             NaN           NaN            NaN            NaN
#
#        bicarbonate_mean  bicarbonate_sd  bicarbonate_min  bicarbonate_max  \
# 0             25.250000        3.105295             18.0             28.0
# 1             23.000000        1.414214             22.0             24.0
# 2             23.333333        2.081666             21.0             25.0
# 3                   NaN             NaN              NaN              NaN
# 4             24.000000        1.000000             23.0             25.0
# ...                 ...             ...              ...              ...
# 30484         23.125000        2.609556             15.0             26.0
# 30485         29.600000        2.073644             26.0             31.0
# 30486         21.631579        3.451417             17.0             31.0
# 30487         23.500000        1.290994             22.0             25.0
# 30488         24.000000             NaN             24.0             24.0
#
#        calcium_total_mean  calcium_total_sd  ...  urea_nitrogen_mean  \
# 0                7.771429          0.292770  ...           15.571429
# 1                8.900000               NaN  ...            9.000000
# 2                8.000000               NaN  ...           17.333333
# 3                     NaN               NaN  ...                 NaN
# 4                7.733333          0.057735  ...           23.000000
# ...                   ...               ...  ...                 ...
# 30484            8.307143          0.255597  ...           16.000000
# 30485            8.000000          0.216025  ...           13.000000
# 30486            8.100000          0.316228  ...           44.578947
# 30487            8.800000          0.416333  ...           20.750000
# 30488                 NaN               NaN  ...           12.000000
#
#        urea_nitrogen_sd  urea_nitrogen_min  urea_nitrogen_max  \
# 0              4.577377               10.0               21.0
# 1              1.414214                8.0               10.0
# 2              3.214550               15.0               21.0
# 3                   NaN                NaN                NaN
# 4              1.732051               21.0               24.0
# ...                 ...                ...                ...
# 30484          4.662524                8.0               23.0
# 30485          1.224745               12.0               15.0
# 30486         12.102873               28.0               63.0
# 30487          0.957427               20.0               22.0
# 30488          1.414214               11.0               13.0
#
#        white_blood_cells_mean  white_blood_cells_sd  white_blood_cells_min  \
# 0                   26.471429             13.176711                   13.2
# 1                   10.300000              1.272792                    9.4
# 2                   12.471429              1.471637                   10.5
# 3                    4.900000                   NaN                    4.9
# 4                   13.233333              2.203028                   10.7
# ...                       ...                   ...                    ...
# 30484               14.134783              3.781727                    8.1
# 30485               12.600000              0.605530                   12.0
# 30486               10.076190              2.642329                    5.3
# 30487                9.900000              1.210372                    7.9
# 30488               18.300000              3.394113                   15.9
#
#        white_blood_cells_max  age  icu_los_hours
# 0                       43.9   48            141
# 1                       11.2   44             30
# 2                       14.3   47             51
# 3                        4.9   33             10
# 4                       14.7   85             41
# ...                      ...  ...            ...
# 30484                   22.1   41            499
# 30485                   13.3   26             67
# 30486                   14.5   74            152
# 30487                   11.0   87             46
# 30488                   20.7   49             31
#
# [30489 rows x 90 columns]

# %% [markdown]
# trying out feature engineering

# %%
# X["renal_ratio"] = X["urea_nitrogen_mean"] / (X["creatinine_mean"] + 1e-5)
# X["creatinine_range"] = X["creatinine_max"] - X["creatinine_min"]
# X["bun_range"] = X["urea_nitrogen_max"] - X["urea_nitrogen_min"]

# X["anion_gap_bicarb_ratio"] = X["anion_gap_mean"] / (X["bicarbonate_mean"] + 1e-5)
# X["anion_gap_range"] = X["anion_gap_max"] - X["anion_gap_min"]

# X["hb_hct_ratio"] = X["hemoglobin_mean"] / (X["hematocrit_mean"] + 1e-5)
# X["rbc_variability"] = X["red_blood_cells_sd"]
# X["plt_range"] = X["platelet_count_max"] - X["platelet_count_min"]

# X["sodium_range"] = X["sodium_max"] - X["sodium_min"]
# X["potassium_range"] = X["potassium_max"] - X["potassium_min"]
# X["chloride_range"] = X["chloride_max"] - X["chloride_min"]

# X["glucose_range"] = X["glucose_max"] - X["glucose_min"]
# X["glucose_instability"] = X["glucose_sd"]

# X["age_los_interaction"] = X["age"] * X["icu_los_hours"]
# X["icu_los_log"] = np.log1p(X["icu_los_hours"])

# X

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.30, random_state=7, stratify=y, shuffle=True)
X_train, X_eval, y_train, y_eval = train_test_split(X_train_full, y_train_full, test_size=0.30, random_state=7, stratify=y_train_full, shuffle=True)

# %%
def objective(trial):

    params = {
        "iterations": trial.suggest_int("iterations", 500, 3000),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "depth": trial.suggest_int("depth", 4, 10),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-2, 10, log=True),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0, 5),
        "random_strength": trial.suggest_float("random_strength", 0, 2),
        "border_count": trial.suggest_int("border_count", 32, 255),
        "random_seed": 42,
        "loss_function": "Logloss",
        "eval_metric": "AUC",
        "task_type": "CPU",
        "verbose": False,
        "od_type": "Iter",
        "od_wait": 120
    }

    model = CatBoostClassifier(**params)
    model.fit(catboost.Pool(X_train, y_train), eval_set=catboost.Pool(X_eval, y_eval), verbose=False)
    pred_val = model.predict_proba(X_eval)[:, 1]
    val_auc = roc_auc_score(y_eval, pred_val)

    return val_auc

# %% [markdown]
# hyperparameter search - TPE

# %%
sampler = optuna.samplers.TPESampler(seed=7)
study = optuna.create_study(direction="maximize", sampler=sampler)

study.optimize(objective, n_trials=50, show_progress_bar=True)

print("Best Trial:")
print(study.best_trial.params)
# Out:
# [I 2025-12-01 13:08:07,352] A new study created in memory with name: no-name-49af8425-64a7-4862-b629-96450d32c2c3
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-12-01 13:08:11,750] Trial 0 finished with value: 0.6965660542432196 and parameters: {'iterations': 690, 'learning_rate': 0.08549750026376444, 'depth': 7, 'l2_leaf_reg': 1.4804560990495679, 'bagging_temperature': 4.889947559983013, 'random_strength': 1.0769917408208673, 'border_count': 144}. Best is trial 0 with value: 0.6965660542432196.
# [I 2025-12-01 13:08:20,366] Trial 1 finished with value: 0.6974851980711713 and parameters: {'iterations': 680, 'learning_rate': 0.004623340751759673, 'depth': 7, 'l2_leaf_reg': 1.090661513591819, 'bagging_temperature': 4.018695180521878, 'random_strength': 0.7618822662970768, 'border_count': 46}. Best is trial 1 with value: 0.6974851980711713.
# [I 2025-12-01 13:08:23,193] Trial 2 finished with value: 0.6929151661274899 and parameters: {'iterations': 1220, 'learning_rate': 0.17913211790965036, 'depth': 5, 'l2_leaf_reg': 0.22718093648132454, 'bagging_temperature': 4.656030098445108, 'random_strength': 0.049798455100696026, 'border_count': 166}. Best is trial 1 with value: 0.6974851980711713.
# [I 2025-12-01 13:09:37,183] Trial 3 finished with value: 0.7069396121996379 and parameters: {'iterations': 2876, 'learning_rate': 0.00371953077740305, 'depth': 7, 'l2_leaf_reg': 5.338080571984234, 'bagging_temperature': 0.6658472287962508, 'random_strength': 1.0468251613475317, 'border_count': 200}. Best is trial 3 with value: 0.7069396121996379.
. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:23:57,714] Trial 27 finished with value: 0.7097143380333271 and parameters: {'iterations': 2268, 'learning_rate': 0.007459783005623385, 'depth': 6, 'l2_leaf_reg': 4.994407310667609, 'bagging_temperature': 1.548095704714647, 'random_strength': 1.2776689416806946, 'border_count': 98}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:24:28,824] Trial 28 finished with value: 0.6962290687501272 and parameters: {'iterations': 1751, 'learning_rate': 0.0020137448648118892, 'depth': 7, 'l2_leaf_reg': 5.402278492207264, 'bagging_temperature': 1.4125901659580173, 'random_strength': 1.2818425046276838, 'border_count': 99}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:25:02,366] Trial 29 finished with value: 0.7081494537020082 and parameters: {'iterations': 2584, 'learning_rate': 0.00578628329600603, 'depth': 5, 'l2_leaf_reg': 9.14568007092408, 'bagging_temperature': 0.9579820001531762, 'random_strength': 1.4615924149794761, 'border_count': 123}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:26:28,642] Trial 30 finished with value: 0.6994842214490631 and parameters: {'iterations': 1998, 'learning_rate': 0.0020337170670930494, 'depth': 9, 'l2_leaf_reg': 5.249027042644622, 'bagging_temperature': 1.7739290380964183, 'random_strength': 1.7990964603454667, 'border_count': 148}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:26:58,083] Trial 31 finished with value: 0.708553581965045 and parameters: {'iterations': 2619, 'learning_rate': 0.005904378666575715, 'depth': 5, 'l2_leaf_reg': 8.822246748513583, 'bagging_temperature': 0.8943370628673594, 'random_strength': 1.4444229967142816, 'border_count': 115}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:27:22,772] Trial 32 finished with value: 0.7016259232130867 and parameters: {'iterations': 2210, 'learning_rate': 0.004299328962055634, 'depth': 5, 'l2_leaf_reg': 1.8275798832334793, 'bagging_temperature': 0.354118747132271, 'random_strength': 1.6025350173766733, 'border_count': 97}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:27:58,826] Trial 33 finished with value: 0.7106230543856438 and parameters: {'iterations': 2763, 'learning_rate': 0.008816292126651033, 'depth': 7, 'l2_leaf_reg': 9.897585159769417, 'bagging_temperature': 1.0401972257563772, 'random_strength': 1.1753951051617237, 'border_count': 149}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:28:20,169] Trial 34 finished with value: 0.7080622189668152 and parameters: {'iterations': 2805, 'learning_rate': 0.019448570525886107, 'depth': 7, 'l2_leaf_reg': 4.8018013049657915, 'bagging_temperature': 1.5349125718460015, 'random_strength': 1.1755762694312004, 'border_count': 152}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:29:08,431] Trial 35 finished with value: 0.7069571608781461 and parameters: {'iterations': 2214, 'learning_rate': 0.008766879375381393, 'depth': 7, 'l2_leaf_reg': 3.6094230173471655, 'bagging_temperature': 2.2125556003767795, 'random_strength': 1.8609943161934834, 'border_count': 181}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:29:52,919] Trial 36 finished with value: 0.7074052880017905 and parameters: {'iterations': 2482, 'learning_rate': 0.004543657386101378, 'depth': 6, 'l2_leaf_reg': 5.992163067522984, 'bagging_temperature': 1.2162937568284766, 'random_strength': 1.0441912012872254, 'border_count': 149}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:30:14,211] Trial 37 finished with value: 0.707115861970742 and parameters: {'iterations': 2813, 'learning_rate': 0.01383838749565685, 'depth': 8, 'l2_leaf_reg': 1.7661689703195298, 'bagging_temperature': 0.3754225170488869, 'random_strength': 1.657712762947642, 'border_count': 66}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:30:23,003] Trial 38 finished with value: 0.7081092697715111 and parameters: {'iterations': 2315, 'learning_rate': 0.03648578406475689, 'depth': 6, 'l2_leaf_reg': 3.448139607463522, 'bagging_temperature': 2.0209777416304955, 'random_strength': 1.2402954292039434, 'border_count': 157}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:30:49,586] Trial 39 finished with value: 0.7022009603450732 and parameters: {'iterations': 2686, 'learning_rate': 0.007675105829516187, 'depth': 7, 'l2_leaf_reg': 0.40312380988096547, 'bagging_temperature': 1.0458551946596943, 'random_strength': 0.9475789378311079, 'border_count': 136}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:31:06,617] Trial 40 finished with value: 0.6958368939347698 and parameters: {'iterations': 852, 'learning_rate': 0.003701260373337015, 'depth': 7, 'l2_leaf_reg': 0.9892003044694065, 'bagging_temperature': 0.376526661649939, 'random_strength': 1.3796328745031627, 'border_count': 178}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:31:36,522] Trial 41 finished with value: 0.708918797940955 and parameters: {'iterations': 2567, 'learning_rate': 0.005970077119212783, 'depth': 5, 'l2_leaf_reg': 9.975463981078674, 'bagging_temperature': 0.8169584235616161, 'random_strength': 1.498464103663802, 'border_count': 112}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:31:53,187] Trial 42 finished with value: 0.7066326374900812 and parameters: {'iterations': 2870, 'learning_rate': 0.012304547340041902, 'depth': 4, 'l2_leaf_reg': 6.918763807319692, 'bagging_temperature': 0.8596902434297904, 'random_strength': 1.5642671342268188, 'border_count': 90}. Best is trial 6 with value: 0.7107842987649801.
# [I 2025-12-01 13:32:23,063] Trial 43 finished with value: 0.7118547681539807 and parameters: {'iterations': 2505, 'learning_rate': 0.009190006064080882, 'depth': 6, 'l2_leaf_reg': 9.602259452134957, 'bagging_temperature': 1.252509736327765, 'random_strength': 1.296447921166327, 'border_count': 107}. Best is trial 43 with value: 0.7118547681539807.
# [I 2025-12-01 13:32:47,411] Trial 44 finished with value: 0.7093692140226657 and parameters: {'iterations': 2143, 'learning_rate': 0.00965335383543509, 'depth': 6, 'l2_leaf_reg': 4.525037952362644, 'bagging_temperature': 1.9069094393343802, 'random_strength': 1.1381576715804083, 'border_count': 124}. Best is trial 43 with value: 0.7118547681539807.
# [I 2025-12-01 13:33:05,389] Trial 45 finished with value: 0.7077488860404078 and parameters: {'iterations': 2475, 'learning_rate': 0.01903135183689279, 'depth': 6, 'l2_leaf_reg': 2.372981015074912, 'bagging_temperature': 1.4460307117085116, 'random_strength': 1.3218397143279748, 'border_count': 196}. Best is trial 43 with value: 0.7118547681539807.
# [I 2025-12-01 13:33:10,049] Trial 46 finished with value: 0.7041104600297056 and parameters: {'iterations': 2340, 'learning_rate': 0.09964412964690514, 'depth': 7, 'l2_leaf_reg': 6.205319144145242, 'bagging_temperature': 1.6454786933359131, 'random_strength': 0.8406737366549843, 'border_count': 140}. Best is trial 43 with value: 0.7118547681539807.
# [I 2025-12-01 13:33:35,536] Trial 47 finished with value: 0.7026735030214246 and parameters: {'iterations': 1960, 'learning_rate': 0.003677479039645781, 'depth': 6, 'l2_leaf_reg': 0.2133816653317895, 'bagging_temperature': 1.2289989289941343, 'random_strength': 1.0234698045821924, 'border_count': 86}. Best is trial 43 with value: 0.7118547681539807.
# [I 2025-12-01 13:34:27,214] Trial 48 finished with value: 0.6939563877189769 and parameters: {'iterations': 2258, 'learning_rate': 0.0010194651690740078, 'depth': 8, 'l2_leaf_reg': 1.140055801282568, 'bagging_temperature': 2.79764187139361, 'random_strength': 1.8829894104356586, 'border_count': 106}. Best is trial 43 with value: 0.7118547681539807.
# [I 2025-12-01 13:34:51,740] Trial 49 finished with value: 0.7107189362957537 and parameters: {'iterations': 1769, 'learning_rate': 0.008277251294698357, 'depth': 7, 'l2_leaf_reg': 3.3915309203371042, 'bagging_temperature': 2.2678647764989863, 'random_strength': 1.37618525955771, 'border_count': 69}. Best is trial 43 with value: 0.7118547681539807.
# Best Trial:
# {'iterations': 2505, 'learning_rate': 0.009190006064080882, 'depth': 6, 'l2_leaf_reg': 9.602259452134957, 'bagging_temperature': 1.252509736327765, 'random_strength': 1.296447921166327, 'border_count': 107}

# %% [markdown]
# Retraining using the best parameters

# %%
best_params = study.best_trial.params
best_params.update({
    "loss_function": "Logloss",
    "eval_metric": "AUC",
    "random_seed": 7,
    "task_type": "CPU",
    "verbose": 200
})

final_model = CatBoostClassifier(**best_params)
final_model.fit(X_train_full, y_train_full)
# Out:
# 0:	total: 13.8ms	remaining: 34.6s
# 200:	total: 2.8s	remaining: 32.1s
# 400:	total: 5.58s	remaining: 29.3s
# 600:	total: 8.39s	remaining: 26.6s
# 800:	total: 11.1s	remaining: 23.6s
# 1000:	total: 13.8s	remaining: 20.7s
# 1200:	total: 16.6s	remaining: 18s
# 1400:	total: 19.2s	remaining: 15.2s
# 1600:	total: 21.9s	remaining: 12.4s
# 1800:	total: 24.6s	remaining: 9.63s
# 2000:	total: 27.4s	remaining: 6.91s
# 2200:	total: 30.1s	remaining: 4.16s
# 2400:	total: 32.8s	remaining: 1.42s
# 2504:	total: 34.3s	remaining: 0us

# %% [markdown]
# Evaluate

# %%
# calculate training error
y_train_pred = final_model.predict(X_train_full)
train_error = np.mean(y_train_pred != y_train_full)
print(f"Training error (Vanilla LR): {train_error:.3f}")

# calculate test error
y_pred = final_model.predict(X_test)
y_pred_proba = final_model.predict_proba(X_test)[:, 1]
test_error = np.mean(y_pred != y_test)
print(f"Test error (Vanilla LR): {test_error:.3f}")
# Out:
# Training error (Vanilla LR): 0.095
# Test error (Vanilla LR): 0.107

# %%
print("Classification Report:\n")
print(classification_report(y_test, y_pred, target_names=["No Readmission (0)", "Readmission (1)"]))

fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba, pos_label=1)
roc_auc = auc(fpr, tpr)
np.savez('../results/catboost_hyperOpt_fpr_tpr_thresholds.npz', fpr, tpr, thresholds)
print(f"AUROC for class 1 (Readmission): {roc_auc:.3f}")

auc, lower, upper = bootstrap_auc_ci(y_test, y_pred_proba)
print(f"AUC = {auc:.4f}, 95% CI = [{lower:.4f}, {upper:.4f}]")
# Out:
# Classification Report:
#
#                     precision    recall  f1-score   support
#
# No Readmission (0)       0.89      1.00      0.94      8164
#    Readmission (1)       0.62      0.01      0.03       983
#
#           accuracy                           0.89      9147
#          macro avg       0.76      0.51      0.48      9147
#       weighted avg       0.86      0.89      0.84      9147
#
# AUROC for class 1 (Readmission): 0.737
# AUC = 0.7364, 95% CI = [0.7204, 0.7528]
